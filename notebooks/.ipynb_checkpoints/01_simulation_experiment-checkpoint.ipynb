# %% [markdown]
# # 01 — Simulation Experiment
# Synthetic RCT with zero-inflated revenue and heterogeneous treatment effects.

# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# %%
from src.simulate import make_synthetic
df = make_synthetic(n=200_000, tau=0.2, zi=0.6, seed=13)
df.head()
# Out:
#          x0        x1        x2        x3        x4        x5        x6  \
# 0  1.826757 -3.078332  0.958064  0.069637  1.318250  0.385629  1.827259
# 1  0.432107 -0.356839 -0.247304  0.719441  0.704316 -0.493934 -0.367714
# 2  1.337277  0.417466  1.943963  1.537110  0.318298  1.480763 -0.950124
# 3  1.064876  0.223632 -0.367137 -0.805560 -0.342800  1.051125  0.890839
# 4 -1.449874 -0.530855 -0.734828  0.743265  0.235950  0.461855  0.272408
#
#          x7        x8        x9  user_id  t         y        y0        y1  \
# 0  0.031744 -0.516229  0.580485        0  1  5.022047  2.881423  5.022047
# 1 -1.806790  1.679207 -0.224291        1  0  0.000000  0.000000  2.560253
# 2  1.258618 -1.480424  0.343236        2  1  1.604804  7.231622  1.604804
# 3 -0.262131 -1.246004  0.673997        3  1  2.293889  1.500059  2.293889
# 4 -0.677930  0.535476  1.412460        4  0  0.000000  0.000000  0.000000
#
#     ps         s       hte
# 0  0.5  0.507756  0.162855
# 1  0.5 -0.324325  0.148692
# ...
